# %%
import urllib.request
from bs4 import BeautifulSoup

#기상청 현재 날씨 페이지 읽기
page = urllib.request.urlopen("http://www.weather.go.kr/weather/observation/currentweather.jsp").read()
soup = BeautifulSoup(page, "html.parser")

#현재 날씨 테이블 검색
table = soup.find("table", {"class":"table_develop3"})

#데이터를 저장할 리스트 생성
data = []

# %%
#모든 <tr>태그를 검색 각 도시의 데이터를 가져옴
for tr in table.find_all("tr"):
    tds = tr.find_all("td")
    for td in tds:
        if td.find("a"):
            point = td.find("a").text
            temperature = tds[5].text
            humidity = tds[9].text
            data.append([point, temperature, humidity])
            
print(data)

with open("weather.csv","w",encoding="utf8") as file:
    file.write("point, temperature, humidity\n")
    for i in data:
        file.write("{0},{1},{2}\n".format(i[0],i[1],i[2]))
# Out:
# [['강릉', '21.6', '79'], ['강진군', '20.9', '93'], ['강화', '19.5', '83'], ['거제', '23.0', '77'], ['거창', '21.4', '79'], ['경주시', '21.6', '85'], ['고산', '23.1', '98'], ['고창', '22.5', '82'], ['고창군', '23.6', '67'], ['고흥', '21.5', '82'], ['광양시', '22.3', '78'], ['광주', '20.6', '99'], ['구미', '22.9', '69'], ['군산', '23.8', '69'], ['금산', '23.1', '69'], ['김해시', '22.9', '70'], ['남원', '21.9', '78'], ['남해', '20.8', '92'], ['대관령', '15.6', '94'], ['대구', '22.9', '71'], ['대전', '24.2', '68'], ['동두천', '20.8', '81'], ['동해', '20.8', '78'], ['목포', '21.2', '94'], ['문경', '21.2', '75'], ['밀양', '23.4', '64'], ['백령도', '21.4', '74'], ['보령', '23.6', '67'], ['보성군', '21.8', '85'], ['보은', '22.3', '69'], ['봉화', '16.9', '88'], ['부산', '22.9', '77'], ['부안', '24.3', '60'], ['부여', '23.3', '73'], ['북강릉', '19.6', '86'], ['북창원', '24.3', '66'], ['북춘천', '22.3', '66'], ['산청', '21.2', '88'], ['상주', '22.4', '74'], ['서귀포', '23.3', '99'], ['서산', '22.3', '69'], ['서울', '23.7', '59'], ['성산', '24.0', '92'], ['세종', '23.8', '61'], ['속초', '20.6', '81'], ['수원', '24.4', '62'], ['순창군', '20.7', '96'], ['순천', '19.7', '99'], ['안동', '20.7', '80'], ['양산시', '23.7', '71'], ['양평', '21.1', '77'], ['여수', '22.7', '74'], ['영광군', '22.2', '83'], ['영덕', '20.7', '91'], ['영월', '19.9', '73'], ['영주', '19.1', '84'], ['영천', '21.6', '79'], ['완도', '21.7', '91'], ['울릉도', '19.6', '88'], ['울산', '22.6', '78'], ['울진', '20.9', '88'], ['원주', '22.8', '60'], ['의령군', '21.7', '87'], ['의성', '22.1', '76'], ['이천', '22.0', '72'], ['인제', '19.0', '80'], ['인천', '24.3', '46'], ['임실', '20.6', '92'], ['장수', '19.0', '99'], ['장흥', '21.7', '81'], ['전주', '24.6', '64'], ['정선군', '18.1', '82'], ['정읍', '23.2', '70'], ['제주', '22.6', '99'], ['제천', '18.9', '86'], ['진도군', '20.4', '95'], ['진주', '21.2', '93'], ['창원', '23.5', '62'], ['천안', '22.5', '69'], ['철원', '20.8', '89'], ['청송군', '20.1', '86'], ['청주', '24.5', '58'], ['추풍령', '21.3', '69'], ['춘천', '22.7', '63'], ['충주', '22.1', '69'], ['태백', '16.3', '87'], ['통영', '22.9', '75'], ['파주', '19.6', '90'], ['포항', '23.8', '73'], ['함양군', '20.7', '87'], ['합천', '22.0', '81'], ['해남', '20.7', '85'], ['홍성', '21.3', '83'], ['홍천', '21.6', '70'], ['흑산도', '21.1', '98']]
