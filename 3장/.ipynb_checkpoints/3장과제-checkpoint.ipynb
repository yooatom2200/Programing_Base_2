# %% [markdown]
# # 3장 예제

# %%
import urllib.request
from bs4 import BeautifulSoup
#기상청 현재 날씨 페이지 읽기
page = urllib.request.urlopen("http://www.weather.go.kr/"+\
                              "weather/observation/currentweather.jsp").read()
soup = BeautifulSoup(page, "html.parser")

#현재 날씨 테이블 검색
table = soup.find("table", {"class":"table_develop3"})

#데이터를 저장할 리스트 생성
data = []

# %%
#모든 <tr>태그를 검색 각 도시의 데이터를 가져옴
for tr in table.find_all("tr"):
    tds = tr.find_all("td")
    for td in tds:
        if td.find("a"):
            point = td.find("a").text
            temperature = tds[5].text
            humidity = tds[9].text
            data.append([point, temperature, humidity])
            
print(data)

with open("weather.csv","w",encoding="utf8") as file:
    file.write("point, temperature, humidity\n")
    for i in data:
        file.write("{0},{1},{2}\n".format(i[0],i[1],i[2]))
# Out:
# [['강릉', '21.0', '81'], ['강진군', '20.7', '95'], ['강화', '20.3', '78'], ['거제', '22.8', '78'], ['거창', '20.7', '84'], ['경주시', '20.8', '89'], ['고산', '23.3', '98'], ['고창', '21.8', '85'], ['고창군', '22.7', '69'], ['고흥', '21.8', '79'], ['광양시', '22.5', '75'], ['광주', '20.5', '99'], ['구미', '22.7', '70'], ['군산', '23.4', '70'], ['금산', '22.8', '71'], ['김해시', '22.9', '72'], ['남원', '22.0', '76'], ['남해', '21.1', '93'], ['대관령', '14.8', '94'], ['대구', '22.8', '72'], ['대전', '23.8', '71'], ['동두천', '20.5', '82'], ['동해', '20.6', '81'], ['목포', '21.4', '94'], ['문경', '20.7', '79'], ['밀양', '23.0', '67'], ['백령도', '21.2', '76'], ['보령', '23.8', '65'], ['보성군', '22.3', '81'], ['보은', '21.7', '72'], ['봉화', '18.1', '81'], ['부산', '22.9', '77'], ['부안', '23.9', '62'], ['부여', '23.3', '71'], ['북강릉', '19.3', '86'], ['북춘천', '22.6', '64'], ['산청', '20.7', '94'], ['상주', '22.1', '76'], ['서귀포', '23.6', '99'], ['서산', '22.4', '69'], ['서울', '23.0', '62'], ['성산', '24.2', '92'], ['세종', '23.5', '63'], ['수원', '23.9', '64'], ['순창군', '20.7', '95'], ['순천', '19.7', '99'], ['안동', '20.5', '80'], ['양산시', '23.7', '73'], ['양평', '20.2', '90'], ['여수', '22.8', '75'], ['영광군', '22.0', '83'], ['영덕', '20.8', '89'], ['영월', '19.7', '73'], ['영주', '19.2', '88'], ['영천', '21.5', '80'], ['완도', '22.2', '86'], ['울릉도', '19.6', '90'], ['울산', '22.9', '78'], ['울진', '20.7', '86'], ['원주', '22.4', '60'], ['의령군', '21.7', '83'], ['의성', '21.7', '78'], ['이천', '21.9', '71'], ['인제', '19.1', '79'], ['인천', '24.1', '46'], ['임실', '20.1', '97'], ['장수', '18.7', '100'], ['장흥', '22.1', '78'], ['전주', '22.1', '83'], ['정선군', '17.6', '84'], ['정읍', '22.4', '75'], ['제주', '22.7', '100'], ['제천', '18.9', '82'], ['진도군', '20.6', '95'], ['진주', '20.7', '94'], ['창원', '22.0', '71'], ['천안', '22.1', '71'], ['철원', '20.0', '92'], ['청송군', '19.7', '89'], ['청주', '24.6', '59'], ['추풍령', '20.9', '71'], ['충주', '21.7', '70'], ['태백', '16.2', '88'], ['통영', '21.5', '89'], ['파주', '19.9', '87'], ['포항', '23.8', '76'], ['함양군', '20.8', '83'], ['합천', '21.9', '80'], ['해남', '20.4', '87'], ['홍성', '21.6', '80'], ['홍천', '20.8', '72'], ['흑산도', '21.9', '99']]

# %%
#현재시간에 맞는 날씨정보 찾기
datedata = soup.find('input',{'id':'observation_text'})
print(datedata['value'])

#찾은 데이터 스플릿후 확인, 저장
comma_spl = datedata['value'].split('.')
colon_spl = comma_spl.pop(3).split(':')
data_spl = comma_spl + colon_spl
print(data_spl)
# Out:
# 2021.09.16.21:00
# ['2021', '09', '16', '21', '00']

# %%
#종합
#날씨테이블 데이터 추출
for tr in table.find_all("tr"):
    tds = tr.find_all("td")
    for td in tds:
        if td.find("a"):
            point = td.find("a").text
            temperature = tds[5].text
            humidity = tds[9].text
            data.append([point, temperature, humidity])
            
print(data)

#현재시간에 맞는 날씨정보 찾기
datedata = soup.find('input',{'id':'observation_text'})
print(datedata['value'])

#찾은 데이터 스플릿후 확인, 저장
comma_spl = datedata['value'].split('.')
colon_spl = comma_spl.pop(3).split(':')
data_spl = comma_spl + colon_spl
print(data_spl)

with open("weather.csv","w",encoding="utf8") as file:
    file.write("{0}년 {1}월 {2}일 {3}시 {4}분 현재 날씨\n"\
               .format(data_spl[0],data_spl[1],data_spl[2],data_spl[3],data_spl[4]))
    file.write("point, temperature, humidity\n")
    for i in data:
        file.write("{0},{1},{2}\n".format(i[0],i[1],i[2]))
# Out:
# [['강릉', '21.0', '81'], ['강진군', '20.7', '95'], ['강화', '20.3', '78'], ['거제', '22.8', '78'], ['거창', '20.7', '84'], ['경주시', '20.8', '89'], ['고산', '23.3', '98'], ['고창', '21.8', '85'], ['고창군', '22.7', '69'], ['고흥', '21.8', '79'], ['광양시', '22.5', '75'], ['광주', '20.5', '99'], ['구미', '22.7', '70'], ['군산', '23.4', '70'], ['금산', '22.8', '71'], ['김해시', '22.9', '72'], ['남원', '22.0', '76'], ['남해', '21.1', '93'], ['대관령', '14.8', '94'], ['대구', '22.8', '72'], ['대전', '23.8', '71'], ['동두천', '20.5', '82'], ['동해', '20.6', '81'], ['목포', '21.4', '94'], ['문경', '20.7', '79'], ['밀양', '23.0', '67'], ['백령도', '21.2', '76'], ['보령', '23.8', '65'], ['보성군', '22.3', '81'], ['보은', '21.7', '72'], ['봉화', '18.1', '81'], ['부산', '22.9', '77'], ['부안', '23.9', '62'], ['부여', '23.3', '71'], ['북강릉', '19.3', '86'], ['북춘천', '22.6', '64'], ['산청', '20.7', '94'], ['상주', '22.1', '76'], ['서귀포', '23.6', '99'], ['서산', '22.4', '69'], ['서울', '23.0', '62'], ['성산', '24.2', '92'], ['세종', '23.5', '63'], ['수원', '23.9', '64'], ['순창군', '20.
['울산', '22.9', '78'], ['울진', '20.7', '86'], ['원주', '22.4', '60'], ['의령군', '21.7', '83'], ['의성', '21.7', '78'], ['이천', '21.9', '71'], ['인제', '19.1', '79'], ['인천', '24.1', '46'], ['임실', '20.1', '97'], ['장수', '18.7', '100'], ['장흥', '22.1', '78'], ['전주', '22.1', '83'], ['정선군', '17.6', '84'], ['정읍', '22.4', '75'], ['제주', '22.7', '100'], ['제천', '18.9', '82'], ['진도군', '20.6', '95'], ['진주', '20.7', '94'], ['창원', '22.0', '71'], ['천안', '22.1', '71'], ['철원', '20.0', '92'], ['청송군', '19.7', '89'], ['청주', '24.6', '59'], ['추풍령', '20.9', '71'], ['충주', '21.7', '70'], ['태백', '16.2', '88'], ['통영', '21.5', '89'], ['파주', '19.9', '87'], ['포항', '23.8', '76'], ['함양군', '20.8', '83'], ['합천', '21.9 ...
# 2021.09.16.21:00
# ['2021', '09', '16', '21', '00']

# %% [markdown]
# # 임의의 프로그램 작성
# ---
# * 오늘의 운세 불러오기
# * 데일리운세(https://unse.daily.co.kr/?p=zodiac)
# * 띠와 연도 구분하여 사용자 정보 입력 후 제공

# %%
#페이지 불러오기
ex_page = urllib.request.urlopen("https://unse.daily.co.kr/?p=zodiac").read()
ex_soup = BeautifulSoup(ex_page, "html.parser")

# %%
correct_input = False
#try:
    #사용자 정보 입력
    z_year = input("당신이 태어년 해 뒤 두자리를 입력해 주세요! - ")
    zodiac = input("당신의 띠(동물)을 입력해 주세요! - ")

    #띠별 인덱스 구하기
    animals = ['쥐', '소', '호랑이','토끼','용','뱀','말','양','원숭이','닭','개','돼지']
    z_code = "code_" + str(animals.index(zodiac) + 1)
    correct_input = true
    
    #년도와 띠 체크
    if z_year % 12 != animals.index(zodiac):
        print("띠와 연도가 틀립니다.")
#except:
    print("정확한 값을 입력해 주세요!")
# Out:
#   File "<ipython-input-74-c9d3a24b369b>", line 4
#     z_year = input("당신이 태어년 해 뒤 두자리를 입력해 주세요! - ")
#     ^
# IndentationError: unexpected indent

# %%
try:
    #웹페이지 운세목록 추출
    fortune = ex_soup.find("ul", {"id":z_code})

    #사용자 정보 확인
    print("-------------사용자 정보-------------")
    print(z_year + "년생 " + zodiac + "띠의 운세입니다.\n\n")

    #띠 공통 운세
    total_text = fortune.find("p").text
    print("--------------공통 운세--------------")
    print(total_text)

    #띠 연도에 맞는 운세
    print("\n\n-------------연도별 운세-------------")
    for i in fortune.find_all("li"):
        if i.find("span").text == str(z_year) + "년생":
            print(i.find("p").text)
except:
    print("검색 오류입니다. 띠와 생년을 확인해주세요!")
# Out:
# -------------사용자 정보-------------
# ㅎㄴㅎ년생 ㅅㅂㅅ띠의 운세입니다.
#
#
# --------------공통 운세--------------
# 전부 다 가질 수는 없다. 개인의 욕심을 조금 내려 놓고 주위를 배려하며 어려운 일에 도움을 준다면 멀지 않아 큰 도움을 받을 수 있다. 배푸는 것 또한 나를 위한 것임을 명심하라.
#
#
# -------------연도별 운세-------------
